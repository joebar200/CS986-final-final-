# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '1.0.5'

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 6C36-7999
#
#  Directory of C:\Users\ruth_\CS986\Spotify
#
# 02/15/2021  11:41 PM    <DIR>          .
# 02/15/2021  11:41 PM    <DIR>          ..
# 02/15/2021  11:07 PM    <DIR>          .ipynb_checkpoints
# 02/01/2021  05:01 PM             6,634 1950.csv
# 02/05/2021  01:23 PM             9,062 1960.csv
# 02/05/2021  01:23 PM             9,152 1970.csv
# 02/05/2021  01:23 PM             8,946 1980.csv
# 02/05/2021  01:23 PM             7,360 1990.csv
# 02/05/2021  01:23 PM             7,987 2000.csv
# 02/05/2021  01:23 PM             8,107 2010.csv
# 02/08/2021  07:14 PM           294,843 Check correlation in all data.ipynb
# 02/15/2021  11:22 PM             1,955 Classification_SVM.csv.csv
# 02/15/2021  11:39 PM             1,955 Classification_SVM42.csv
# 02/15/2021  11:40 PM             1,955 Classification_SVM5.csv
# 02/15/2021  11:29 PM             1,937 Classification_SVM8.csv
# ...

# %%
spot_test = pd.read_csv('CS98XRegressionTest.csv')
spot_train = pd.read_csv('CS98XRegressionTrain.csv')

# %%
spot_1950 = pd.read_csv('1950.csv')
spot_1950.shape
spot_1950['ID'] = 0
num_1950 = spot_1950.shape[0]
for i in range(num_1950):
    spot_1950['ID'][i] = '1950-' + str(i+1)
# Out:
# <ipython-input-23-b59f4d0d1cd5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_1950['ID'][i] = '1950-' + str(i+1)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
spot_1960 = pd.read_csv('1960.csv')
spot_1960.shape
spot_1960['ID'] = 0
num_1960 = spot_1960.shape[0]
for i in range(num_1960):
    spot_1960['ID'][i] = '1960-' + str(i+1)
# Out:
# <ipython-input-24-147d62517f03>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_1960['ID'][i] = '1960-' + str(i+1)

# %%
spot_1970 = pd.read_csv('1970.csv')
spot_1970.shape
spot_1970['ID'] = 0
num_1970 = spot_1970.shape[0]
for i in range(num_1970):
    spot_1970['ID'][i] = '1970-' + str(i+1)
# Out:
# <ipython-input-25-c34aa80e1a63>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_1970['ID'][i] = '1970-' + str(i+1)

# %%
spot_1980 = pd.read_csv('1980.csv')
spot_1980.shape
spot_1980['ID'] = 0
num_1980 = spot_1980.shape[0]
for i in range(num_1980):
    spot_1980['ID'][i] = '1980-' + str(i+1)
# Out:
# <ipython-input-26-1a91642d0e11>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_1980['ID'][i] = '1980-' + str(i+1)

# %%
spot_1990 = pd.read_csv('1990.csv')
spot_1990.shape
spot_1990['ID'] = 0
num_1990 = spot_1990.shape[0]
for i in range(num_1990):
    spot_1990['ID'][i] = '1990-' + str(i+1)
# Out:
# <ipython-input-27-a4e8f175ed16>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_1990['ID'][i] = '1990-' + str(i+1)

# %%
spot_2000 = pd.read_csv('2000.csv')
spot_2000.shape
spot_2000['ID'] = 0
num_2000 = spot_2000.shape[0]
for i in range(num_2000):
    spot_2000['ID'][i] = '2000-' + str(i+1)
# Out:
# <ipython-input-28-bd66ce2d40e5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_2000['ID'][i] = '2000-' + str(i+1)

# %%
spot_2010 = pd.read_csv('2010.csv')
spot_2010.shape
spot_2010['ID'] = 0
num_2010 = spot_2010.shape[0]
for i in range(num_2010):
    spot_2010['ID'][i] = '2010-' + str(i+1)
# Out:
# <ipython-input-29-a9a6593099c5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spot_2010['ID'][i] = '2010-' + str(i+1)

# %%
spot_1960.head()
# Out:
#    Number                                 title         artist  \
# 0       1  Here Comes The Sun - Remastered 2009    The Beatles
# 1       2       Come Together - Remastered 2009    The Beatles
# 2       3                        Sweet Caroline   Neil Diamond
# 3       4           Yesterday - Remastered 2009    The Beatles
# 4       5            Can't Help Falling in Love  Elvis Presley
#
#           top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0  british invasion  1969  129    54    56 -10    18   39  186      3     3
# 1  british invasion  1969  165    38    53 -12     9   19  260      3     4
# 2   adult standards  1969   63    13    53 -16    24   58  204     61     3
# 3  british invasion  1965   97    18    33 -12     9   32  126     88     3
# 4   adult standards  1961  100    29    40 -14    11   34  182     94     3
#
#    pop      ID
# 0   82  1960-1
# 1   79  1960-2
# 2   78  1960-3
# 3   78  1960-4
# 4   78  1960-5

# %%
frames = [spot_1950, spot_1960, spot_1970, spot_1980, spot_1990, spot_2000, spot_2010]

combine_spot = pd.concat(frames)

# %%
combine_spot.shape
# Out:
# (667, 16)

# %%
combine_spot.head()
# Out:
#    Number                                              title  \
# 0       1                       Put Your Head On My Shoulder
# 1       2  Whatever Will Be Will Be (Que Sera Sera) (with...
# 2       3                           Everybody Loves Somebody
# 3       4        Take Good Care Of My Baby - 1990 Remastered
# 4       5                                 A Teenager In Love
#
#                 artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0            Paul Anka  adult standards  2000  116    34    55  -9    10   47
# 1            Doris Day  adult standards  1948  177    34    42 -11    72   78
# 2          Dean Martin  adult standards  2013   81    49    26  -9    34   40
# 3            Bobby Vee  adult standards  2011   82    43    49 -12    12   66
# 4  Dion & The Belmonts  adult standards  1959   79    38    56  -9    13   62
#
#    dur  acous  spch  pop      ID
# 0  155     75     3   72  1950-1
# 1  123     86     4   62  1950-2
# ...

# %%
combine_spot.describe()
# Out:
#            Number         year         bpm        nrgy        dnce  \
# count  667.000000   667.000000  667.000000  667.000000  667.000000
# mean    48.718141  1994.967016  119.121439   61.394303   60.325337
# std     28.414748    17.771374   25.030827   21.703963   15.051583
# min      1.000000  1945.000000   62.000000    6.000000   18.000000
# 25%     24.000000  1980.000000  101.500000   45.000000   51.000000
# 50%     48.000000  1998.000000  120.000000   64.000000   62.000000
# 75%     72.000000  2010.000000  134.000000   79.000000   71.000000
# max    105.000000  2019.000000  199.000000  100.000000   96.000000
#
#                dB        live         val         dur       acous        spch  \
# count  667.000000  667.000000  667.000000  667.000000  667.000000  667.000000
# mean    -8.356822   18.188906   57.311844  224.002999   29.917541    6.179910
# std      3.659509   14.380929   24.400412   59.742591   28.865081    6.191199
# ...

# %%
combine_spot.isnull().any()
# Out:
# Number       False
# title        False
# artist       False
# top genre     True
# year         False
# bpm          False
# nrgy         False
# dnce         False
# dB           False
# live         False
# val          False
# dur          False
# acous        False
# spch         False
# pop          False
# ID           False
# dtype: bool

# %%
combine_spot = combine_spot.drop('Number', axis =1)

# %%
combine_spot.corr()
# Out:
#            year       bpm      nrgy      dnce        dB      live       val  \
# year   1.000000 -0.020790  0.195329  0.273865  0.422602 -0.001603 -0.087055
# bpm   -0.020790  1.000000  0.179329 -0.057710  0.044748  0.009960  0.084723
# nrgy   0.195329  0.179329  1.000000  0.331962  0.702543  0.132563  0.405190
# dnce   0.273865 -0.057710  0.331962  1.000000  0.295534 -0.069818  0.454714
# dB     0.422602  0.044748  0.702543  0.295534  1.000000  0.083423  0.136813
# live  -0.001603  0.009960  0.132563 -0.069818  0.083423  1.000000  0.060542
# val   -0.087055  0.084723  0.405190  0.454714  0.136813  0.060542  1.000000
# dur   -0.099655  0.038277  0.131228  0.053011  0.026851 -0.067533 -0.118664
# acous -0.241289 -0.175530 -0.665900 -0.382297 -0.504551 -0.056394 -0.196375
# spch   0.193292  0.059116  0.178491  0.207741  0.200195  0.091595  0.053817
# pop    0.160467  0.066558  0.271798  0.249302  0.365172 -0.036505 -0.102418
#
#             dur     acous      spch       pop
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(combine_spot, figsize=(12,7))
plt.show()

# %%
corr_matrix = combine_spot.corr()
corr_matrix
corr_matrix["pop"].sort_values(ascending=False)
# Out:
# pop       1.000000
# dB        0.365172
# dur       0.280501
# nrgy      0.271798
# dnce      0.249302
# spch      0.192929
# year      0.160467
# bpm       0.066558
# live     -0.036505
# val      -0.102418
# acous    -0.455239
# Number   -0.519745
# Name: pop, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["pop", "dB", "dur", "acous"]
scatter_matrix(combine_spot[attributes], figsize=(12,7))
plt.show()

# %%
combine_spot.plot(kind="scatter", x="dur", y="pop",
             alpha=0.1)
plt.show()

# %%
import pandas as pd
import numpy as np
corr = combine_spot.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col1 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col2 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col3 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col4 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_98c338c0_706b_11eb_aef2_087190ad63bbrow0_col6 {
#             background-color:  #5673e0;
#             color:  #000000;
# ...
